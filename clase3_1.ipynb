# %% [markdown]
# # SISD

# %%
import numpy as np
import time

# Creamos dos arrays grandes
a = np.random.rand(10000)
b = np.random.rand(10000)
c = np.empty(10000)

start = time.time()
for i in range(10000):
    c[i] = a[i] + b[i]
end = time.time()

print("Tiempo con bucle for:", end - start, "segundos")
# Out:
# Tiempo con bucle for: 0.006898641586303711 segundos

# %% [markdown]
# # SIMD

# %%
start = time.time()
c = a + b  # Esta operación se realiza en paralelo internamente
end = time.time()

print("Tiempo con NumPy vectorizado:", end - start, "segundos")
# Out:
# Tiempo con NumPy vectorizado: 0.0001201629638671875 segundos

# %% [markdown]
# # Tratamiento de datos
# ## Primeros pasos

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# Creamos un conjunto de datos simple con algunos problemas comunes
data = {
    'ip_origen': ['192.168.1.1', '10.0.0.1', None, '172.16.0.1', '192.168.1.1'],
    'puerto': [80, 443, 22, np.nan, 80],
    'protocolo': ['HTTP', 'https', 'SSH', 'http', None],
    'intentos_acceso': [5, 10, None, 7, 5],
    'timestamp': ['2023-01-01', '2023-01-01', '2023-01-02', '2023-01-03', '2023-01-01'],
    'exito': [False, True, False, True, False]
}

# Creamos un DataFrame de pandas
df = pd.DataFrame(data)

print("DataFrame original:")
print(df)
print("\n")

# 1. Vemos información básica del DataFrame
print("1. Información básica del DataFrame:")
print(df.info())
print("\n")
# Out:
# DataFrame original:
#      ip_origen  puerto protocolo  intentos_acceso   timestamp  exito
# 0  192.168.1.1    80.0      HTTP              5.0  2023-01-01  False
# 1     10.0.0.1   443.0     https             10.0  2023-01-01   True
# 2         None    22.0       SSH              NaN  2023-01-02  False
# 3   172.16.0.1     NaN      http              7.0  2023-01-03   True
# 4  192.168.1.1    80.0      None              5.0  2023-01-01  False
#
#
# 1. Información básica del DataFrame:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5 entries, 0 to 4
# Data columns (total 6 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   ip_origen        4 non-null      object
#  1   puerto           4 non-null      float64
#  2   protocolo        4 non-null      object
#  3   intentos_acceso  4 non-null      float64
#  4   timestamp        5 non-null      object
#  5   exito            5 non-null      bool
# dtypes: bool(1), float64(2), object(3)
# memory usage: 337.0+ bytes
# None

# %%
# 2. Vemos estadísticas descriptivas
print("2. Estadísticas descriptivas:")
print(df.describe())
print("\n")
# Out:
# 2. Estadísticas descriptivas:
#            puerto  intentos_acceso
# count    4.000000         4.000000
# mean   156.250000         6.750000
# std    193.112014         2.362908
# min     22.000000         5.000000
# 25%     65.500000         5.000000
# 50%     80.000000         6.000000
# 75%    170.750000         7.750000
# max    443.000000        10.000000

# %%
# 3. Verificamos valores nulos
print("3. Valores nulos por columna:")
print(df.isnull().sum())
print("\n")
# Out:
# 3. Valores nulos por columna:
# ip_origen          1
# puerto             1
# protocolo          1
# intentos_acceso    1
# timestamp          0
# exito              0
# dtype: int64

# %%
# 4. Eliminamos registros duplicados
df_sin_duplicados = df.drop_duplicates()
print("DataFrame sin registros duplicados:")
print(df_sin_duplicados)
print("\n")
# Out:
# DataFrame sin registros duplicados:
#      ip_origen  puerto protocolo  intentos_acceso   timestamp  exito
# 0  192.168.1.1    80.0      HTTP              5.0  2023-01-01  False
# 1     10.0.0.1   443.0     https             10.0  2023-01-01   True
# 2         None    22.0       SSH              NaN  2023-01-02  False
# 3   172.16.0.1     NaN      http              7.0  2023-01-03   True
# 4  192.168.1.1    80.0      None              5.0  2023-01-01  False

# %% [markdown]
# ## Código para añadir una fila y eliminarla

# %%
fila_duplicada= df.iloc[[1]]
print(df)

# Duplica la fila concatenándola al DataFrame original
df = pd.concat([df, fila_duplicada], ignore_index=True)
# Out:
#       ip_origen  puerto protocolo  intentos_acceso   timestamp  exito
# 0   192.168.1.1    80.0      HTTP              5.0  2023-01-01  False
# 1      10.0.0.1   443.0     https             10.0  2023-01-01   True
# 2          None    22.0       SSH              NaN  2023-01-02  False
# 3    172.16.0.1     NaN      http              7.0  2023-01-03   True
# 4   192.168.1.1    80.0      None              5.0  2023-01-01  False
# 5      10.0.0.1   443.0     https             10.0  2023-01-01   True
# 6      10.0.0.1   443.0     https             10.0  2023-01-01   True
# 7      10.0.0.1   443.0     https             10.0  2023-01-01   True
# 8      10.0.0.1   443.0     https             10.0  2023-01-01   True
# 9      10.0.0.1   443.0     https             10.0  2023-01-01   True
# 10     10.0.0.1   443.0     https             10.0  2023-01-01   True
# 11     10.0.0.1   443.0     https             10.0  2023-01-01   True
# 1      10.0.0.1   443.0     https             10.0  2023-01-01   True
# 1      10.0.0.1   443.0     https             10.0  2023-01-01   True
# 1      10.0.0.1   443.0     https             10.0  2023-01-01   True
# 1      10.0.0.1   443.0     https             10.0  2023-01-01   True

# %% [markdown]
# ## Eliminar duplicados nuevamente

# %%
# 4. Eliminamos registros duplicados
df_sin_duplicados = df.drop_duplicates()
print("DataFrame sin registros duplicados:")
print(df_sin_duplicados)
print("\n")
# Out:
# DataFrame sin registros duplicados:
#      ip_origen  puerto protocolo  intentos_acceso   timestamp  exito
# 0  192.168.1.1    80.0      HTTP              5.0  2023-01-01  False
# 1     10.0.0.1   443.0     https             10.0  2023-01-01   True
# 2         None    22.0       SSH              NaN  2023-01-02  False
# 3   172.16.0.1     NaN      http              7.0  2023-01-03   True
# 4  192.168.1.1    80.0      None              5.0  2023-01-01  False

# %%
# 5. Manejamos valores nulos
## 5.1 Para valores categóricos, rellenamos con 'DESCONOCIDO'
df['ip_origen'].fillna('DESCONOCIDO', inplace=True)
df['protocolo'].fillna('DESCONOCIDO', inplace=True)
# Out:
# /tmp/ipykernel_40248/1293995984.py:3: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['ip_origen'].fillna('DESCONOCIDO', inplace=True)
# /tmp/ipykernel_40248/1293995984.py:4: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['protocolo'].fillna('DESCONOCIDO', inplace=True)

# %%
print(df)
# Out:
#       ip_origen  puerto    protocolo  intentos_acceso   timestamp  exito
# 0   192.168.1.1    80.0         HTTP              5.0  2023-01-01  False
# 1      10.0.0.1   443.0        https             10.0  2023-01-01   True
# 2   DESCONOCIDO    22.0          SSH              NaN  2023-01-02  False
# 3    172.16.0.1     NaN         http              7.0  2023-01-03   True
# 4   192.168.1.1    80.0  DESCONOCIDO              5.0  2023-01-01  False
# 5      10.0.0.1   443.0        https             10.0  2023-01-01   True
# 6      10.0.0.1   443.0        https             10.0  2023-01-01   True
# 7      10.0.0.1   443.0        https             10.0  2023-01-01   True
# 8      10.0.0.1   443.0        https             10.0  2023-01-01   True
# 9      10.0.0.1   443.0        https             10.0  2023-01-01   True
# 10     10.0.0.1   443.0        https             10.0  2023-01-01   True
# 11     10.0.0.1   443.0        https             10.0  2023-01-01   True
# 1      10.0.0.1   443.0        https             10.0  2023-01-01   True
# 1      10.0.0.1   443.0        https             10.0  2023-01-01   True
# 1      10.0.0.1   443.0        https             10.0  2023-01-01   True
# 1      10.0.0.1   443.0        https             10.0  2023-01-01   True
# 1      10.0.0.1   443.0        https             10.0  2023-01-01   True

# %%
# 5.2 Para valores numéricos, rellenamos con la media
df['puerto'].fillna(df['puerto'].mean(), inplace=True)
df['intentos_acceso'].fillna(df['intentos_acceso'].mean(), inplace=True)


print(df)
# Out:
#       ip_origen    puerto    protocolo  intentos_acceso   timestamp  exito
# 0   192.168.1.1   80.0000         HTTP           5.0000  2023-01-01  False
# 1      10.0.0.1  443.0000        https          10.0000  2023-01-01   True
# 2   DESCONOCIDO   22.0000          SSH           9.1875  2023-01-02  False
# 3    172.16.0.1  371.3125         http           7.0000  2023-01-03   True
# 4   192.168.1.1   80.0000  DESCONOCIDO           5.0000  2023-01-01  False
# 5      10.0.0.1  443.0000        https          10.0000  2023-01-01   True
# 6      10.0.0.1  443.0000        https          10.0000  2023-01-01   True
# 7      10.0.0.1  443.0000        https          10.0000  2023-01-01   True
# 8      10.0.0.1  443.0000        https          10.0000  2023-01-01   True
# 9      10.0.0.1  443.0000        https          10.0000  2023-01-01   True
# 10     10.0.0.1  443.0000        https          10.0000  2023-01-01   True
# 11     10.0.0.1  443.0000        https          10.0000  2023-01-01   True
# 1      10.0.0.1  443.0000        https          10.0000  2023-01-01   True
# 1      10.0.0.1  443.0000        https          10.0000  2023-01-01   True
# 1      10.0.0.1  443.0000        https          10.0000  2023-01-01   True
# 1      10.0.0.1  443.0000        https          10.0000  2023-01-01   True
# 1      10.0.0.1  443.0000        https          10.0000  2023-01-01   True
# /tmp/ipykernel_40248/4179443951.py:2: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['puerto'].fillna(df['puerto'].mean(), inplace=True)
# /tmp/ipykernel_40248/4179443951.py:3: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['intentos_acceso'].fillna(df['intentos_acceso'].mean(), inplace=True)

# %%
# 6. Estandarizamos valores (convertimos todos los protocolos a mayúsculas)
df['protocolo'] = df['protocolo'].str.upper()

print("DataFrame después de estandarizar protocolos:")
print(df)
print("\n")
# Out:
# DataFrame después de estandarizar protocolos:
#       ip_origen    puerto    protocolo  intentos_acceso   timestamp  exito  \
# 0   192.168.1.1   80.0000         HTTP           5.0000  2023-01-01  False
# 1      10.0.0.1  443.0000        HTTPS          10.0000  2023-01-01   True
# 2   DESCONOCIDO   22.0000          SSH           9.1875  2023-01-02  False
# 3    172.16.0.1  371.3125         HTTP           7.0000  2023-01-03   True
# 4   192.168.1.1   80.0000  DESCONOCIDO           5.0000  2023-01-01  False
# 5      10.0.0.1  443.0000        HTTPS          10.0000  2023-01-01   True
# 6      10.0.0.1  443.0000        HTTPS          10.0000  2023-01-01   True
# 7      10.0.0.1  443.0000        HTTPS          10.0000  2023-01-01   True
# 8      10.0.0.1  443.0000        HTTPS          10.0000  2023-01-01   True
# 9      10.0.0.1  443.0000        HTTPS          10.0000  2023-01-01   True
# 10     10.0.0.1  443.0000        HTTPS          10.0000  2023-01-01   True
# 11     10.0.0.1  443.0000        HTTPS          10.0000  2023-01-01   True
# 1      10.0.0.1  443.0000        HTTPS          10.0000  2023-01-01   True
# 1      10.0.0.1  443.0000        HTTPS          10.0000  2023-01-01   True
# 1      10.0.0.1  443.0000        HTTPS          10.0000  2023-01-01   True
# 1      10.0.0.1  443.0000        HTTPS          10.0000  2023-01-01   True
# 1      10.0.0.1  443.0000        HTTPS          10.0000  2023-01-01   True
#
#     es_puerto_comun
# 0              True
# 1              True
# 2              True
# 3             False
# 4              True
# 5              True
# 6              True
# 7              True
# 8              True
# 9              True
# 10             True
# 11             True
# 1              True
# 1              True
# 1              True
# 1              True
# 1              True

# %%
# 7. Creamos una nueva columna basada en cálculos
df['es_puerto_comun'] = df['puerto'].apply(lambda x: x in [80, 443, 22, 21, 25])
print(df)
print("\n")
# Out:
#       ip_origen    puerto    protocolo  intentos_acceso   timestamp  exito  \
# 0   192.168.1.1   80.0000         HTTP           5.0000  2023-01-01  False
# 1      10.0.0.1  443.0000        HTTPS          10.0000  2023-01-01   True
# 2   DESCONOCIDO   22.0000          SSH           9.1875  2023-01-02  False
# 3    172.16.0.1  371.3125         HTTP           7.0000  2023-01-03   True
# 4   192.168.1.1   80.0000  DESCONOCIDO           5.0000  2023-01-01  False
# 5      10.0.0.1  443.0000        HTTPS          10.0000  2023-01-01   True
# 6      10.0.0.1  443.0000        HTTPS          10.0000  2023-01-01   True
# 7      10.0.0.1  443.0000        HTTPS          10.0000  2023-01-01   True
# 8      10.0.0.1  443.0000        HTTPS          10.0000  2023-01-01   True
# 9      10.0.0.1  443.0000        HTTPS          10.0000  2023-01-01   True
# 10     10.0.0.1  443.0000        HTTPS          10.0000  2023-01-01   True
# 11     10.0.0.1  443.0000        HTTPS          10.0000  2023-01-01   True
# 1      10.0.0.1  443.0000        HTTPS          10.0000  2023-01-01   True
# 1      10.0.0.1  443.0000        HTTPS          10.0000  2023-01-01   True
# 1      10.0.0.1  443.0000        HTTPS          10.0000  2023-01-01   True
# 1      10.0.0.1  443.0000        HTTPS          10.0000  2023-01-01   True
# 1      10.0.0.1  443.0000        HTTPS          10.0000  2023-01-01   True
#
#     es_puerto_comun
# 0              True
# 1              True
# 2              True
# 3             False
# 4              True
# 5              True
# 6              True
# 7              True
# 8              True
# 9              True
# 10             True
# 11             True
# 1              True
# 1              True
# 1              True
# 1              True
# 1              True
